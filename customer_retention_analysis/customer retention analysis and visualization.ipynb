# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the Dataset

# %%
df=pd.read_csv("customer_retention_dataset.csv")
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# The above data set is the customer retention dataset where we have 298 rows and 71 columns.
# It has various features which includes gender, age, city and many more around 71 columns.
# The above data is collected from the online shppers from various websites like amazon. flipkart, myntra, snapdeal and paytm.
# The data has collected  to measure what factors contribute the success of e-retail store.
# The data has been analysed and visuallized below.

# %%
#strip of blank spaces in the column name.
df.columns = df.columns.str.strip()

# %%
df.dtypes #datatype of each column.
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you?',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?',
#        '11 What browser do you run on your device to access the website?',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
#        '15 What is your preferred payment Option?',
# ...

# %% [markdown]
# Name of the each column.

# %%
for i in df.columns:
    if df[i].dtypes== object:
        print(df[i].value_counts())
        print("----------")
    else:
        pass
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# ----------
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you?, dtype: int64
# ----------
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
# ----------
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64
# ----------
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# ...

# %% [markdown]
# unique count of each column is calculated.

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %% [markdown]
# # VISUALIZATION AND ANALYSIS

# %%
sns.set_theme(style="darkgrid")
sns.countplot(df['1Gender of respondent'], edgecolor=sns.color_palette("muted", 3), facecolor=(0, 0, 0, 0),
                   linewidth=10)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# From the above plot we can say that, females are more as compared to males or we can say that female buyers are more as compared to male buyers.

# %%
plt.figure(figsize=(12,5))
plt.xticks(rotation=40)
sns.countplot(x='3 Which city do you shop online from?', hue='1Gender of respondent', data=df, palette='dark')
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# From above figure we can conclude that,
# 1. In Delhi, Noida Location, Male buyers are more as compared to female buyers.
# 2. In G.Noida, Karnal, Bangalore Gurgaon, Female buyers are more as compared to males.
# 3. In solan, there are only female buyers.
# 4. In Moradabad, Bulandshahr, there are only male buyers.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="whitegrid")
plt.xticks(rotation=40)
sns.countplot(x='3 Which city do you shop online from?', hue='2 How old are you?', data=df, palette="Accent", edgecolor='black')
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# In the above plot,
# 1. For Delhi Location, people of age group 41-50 years are the higest amoung all to shop online.
# 2. G.Noida, Ghaziabad and Noida, People of age group 31-40 years leads.
# 3. In Karnal, Bangalore and Merrut Location, people of 21-30 years of age are the highest buyers.
# 4. In Solan, less than 20 years of age are the highest shopers.
# 5. In gurgaon Location, 51 years or above are the ones who spends more through online shoping.
# 6. Moradabad and Bulandshahr are the only cities, where the people of age 31-40 years are the only ones who shop online.

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='dark')
sns.countplot(df["2 How old are you?"], palette='Greens',linewidth=3, edgecolor='w')
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# People of age group 31-40 years are the ones who shop the most through online platforms and the people of age group 51 years or above are the least who prefer online shoping.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='whitegrid')
plt.xticks(rotation=40)
g=sns.countplot(x='3 Which city do you shop online from?', hue='6 How many times you have made an online purchase in the past 1 year?', data=df,palette='bright', edgecolor='black')
#g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# From the Above plot we can say that, ploting how many times people shop online versus the location....
# 1. For Delhi, Noida, Karnal, Solan, Bulandsher and Gurgaon Location, majority of people make make online pruchases which is less than 10 times.
# 2. At Greater Noida Location, maximum people did online shoping for 41 times and above.
# 3.  Majority of People at Locations like Merrut and Ghaziabad shop 31-40 times through online platforms.
# 4. At Moradabad Location, purchases made by people through these online websites are 21-30 times.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='darkgrid')
plt.xticks(rotation=40)
g=sns.countplot(x='3 Which city do you shop online from?', hue='5 Since How Long You are Shopping Online ?', data=df, palette='colorblind',edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# Ploting Since how long people are shopping online versus the city, we can say that:
# 1. People at locations like Delhi, G. Noida, Karnal, Noida, Merrut, Moradabad are the ones where mojority of the people are shopping online since past 4 years or above.
# 2. People at Banglaore, Solan and Gurgaon Locations majority of people are shopping online from 2-3 years.
# 3. At Bulandshahr people started surfing online platforms for shopping from 1-2 years only.

# %%
# column how do you access internet while shopping on-line has 4 labels where mobile internet and mobile Internet we considered 2 different categoires so merging them into 1 category.
df["7 How do you access the internet while shopping on-line?"] = df["7 How do you access the internet while shopping on-line?"].str.replace('Mobile Internet', 'Mobile internet')

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='darkgrid')
sns.countplot(x='7 How do you access the internet while shopping on-line?', hue='1Gender of respondent', data=df, palette='pastel', edgecolor='black', linewidth=2)
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# 3 categories via people shop online are plotted in above figure where females leads in 2 categories i.e wifi and mobile internet on the other hand males prefer dial=up mode for shoping online.

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='darkgrid')
plt.xticks(rotation=40)
g=sns.countplot(hue='7 How do you access the internet while shopping on-line?', x='3 Which city do you shop online from?', data=df, palette='dark')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# From above plot we can say that, majority of the people in irresepective of there location preffer mobile internet to shop online. In the city like Gurgaon people only use wi-fi to shop online and Delhi is the only location where sfew people prefer Dail-up mode ofr shopping online.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=40)
sns.countplot(x='3 Which city do you shop online from?', hue='12 Which channel did you follow to arrive at your favorite online store for the first time?', data=df, palette='colorblind', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# Majority of people irrespective of cities use search engines to arrive at there favourite online stores whereas bulandshahr is the only location where people dont use any other mode except content marketing to arrive at there favourite online platform.

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='2 How old are you?', hue='12 Which channel did you follow to arrive at your favorite online store for the first time?', data=df, edgecolor='black')
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# People irrespective of age....preferre serach engines to arrive at there favourite online platform.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=40)
g=sns.countplot(hue='13 After first visit, how do you reach the online retail store?', x='3 Which city do you shop online from?', data=df, palette='colorblind',edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# In the above plot,
# 1. People in Delhi, Karnal, Bulanshahr and Merrut preffer to use search engines to visit there favourite online store even they have explored that store perviously.
# 2. People in Locations like G.Noida, Bagalore, Ghaziabad after exploring the platform for the first time they preffer downloading the application and probably use use applicattion to make purchases.
# 3. People in Noida, Solan, Gurgaon and Moradabad use the Direct links of there favourite stores to make online purchases.

# %%
plt.figure(figsize=(12,5))
sns.countplot(hue='13 After first visit, how do you reach the online retail store?', x='1Gender of respondent', data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# In the above plot, Majority of males preffer earch Engines or Direct Urls to visit online stores even though once they have explored that store whereas females after exploring the online store for once prefer to download the respective application and make furthur purchases via application only.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='dark')
plt.xticks(rotation=40)
g=sns.countplot(hue='14 How much time do you explore the e- retail store before making a purchase decision?', x='3 Which city do you shop online from?', data=df, palette='pastel', edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# In the above Figure, the time people take to explore website before making any purchase versus city.....
# 1. People at Delhi, Bangalore, Noida, Solan, Gurgaon spends more that 15 mints on the platform before making any purchase.
# 2. People at G.Noida Spends 11-15 mints before making nay purchase.
# 3. Karnal, Moradabad and Bulandshahr locations people spend 6-10 mints before making any purchase.

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='darkgrid')
g=sns.countplot(hue='14 How much time do you explore the e- retail store before making a purchase decision?', x='1Gender of respondent', data=df, edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# The above plot depicts the very obvious nature of women which says women spend more time at e-retail before making nay purchase as compared to male.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='darkgrid')
plt.xticks(rotation=40)

g=sns.countplot(hue='15 What is your preferred payment Option?',x='3 Which city do you shop online from?', data=df, palette='muted', edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# Most of the people at different locations prefer debit and credit card payments where as cities like solan people prefer COD mode and in the city like bulandshahr people only shop via COD mode of payment.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='darkgrid')
#plt.xticks(rotation=40)
g=sns.countplot(hue='14 How much time do you explore the e- retail store before making a purchase decision?', x='2 How old are you?', data=df, palette='muted', edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# Most of the people irrespective of there age spends more that 15 mints to make any decision before purchasing whereas majority of people who are below 20 years of age spends hardly 1-5 mints before making any purchase.

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='2 How old are you?', hue='15 What is your preferred payment Option?', data=df, palette='muted', edgecolor='black' )
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# People above 20 years of age use credit/debit cards to make online purchases wherease people below 20 years uses COD.

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='darkgrid')
g=sns.countplot(x='2 How old are you?', hue='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?', data=df, palette='colorblind', edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# Most of the people irrespective of there age abondon there shopping carts without making any payments.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='darkgrid')
plt.xticks(rotation=40)
g=sns.countplot(x='3 Which city do you shop online from?', hue='17 Why did you abandon the �Bag�, �Shopping Cart�?', data=df, palette='muted', edgecolor='black' )
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# Majority of people at different locations abondon there shopping bags because they find better alternative options but people at locations like Moradabad and Merrut abondon there shopping bags because of change in price.

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='dark')

sns.countplot(df['17 Why did you abandon the �Bag�, �Shopping Cart�?'], palette='Reds', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the �Bag�, �Shopping Cart�?', ylabel='count'>

# %% [markdown]
# Majority of people abondon shopping bags because they find better alternatives.

# %%
plt.figure(figsize=(12,5))
sns.set_theme(style='darkgrid')
sns.countplot(x='2 How old are you?', hue='17 Why did you abandon the �Bag�, �Shopping Cart�?', data=df, palette='muted', edgecolor='black' )
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# People above 20 years of age abondoned there shopping bags because of better alternatives avaliable where as people below 20 years abondoned shopping bags because of the no preferred mode of payment available.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='dark')
sns.countplot(df['18 The content on the website must be easy to read and understand'], palette='Spectral',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# People strongly agree that content of the website must be easy to read and understand.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='dark')
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'], palette='Reds', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %% [markdown]
# people strongly agree that information on similar product to the one highlighted is important for product comparision.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'], palette='Greens', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# People Agree that complete information on the listed seller and product being offered is important for decision purchase.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='white')
sns.countplot(df['21 All relevant information on listed products must be stated clearly'],palette='Greys')
# Out:
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %% [markdown]
# People Completely agree that all relevant information on the listed products must be stated clearly on the website.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='dark')
sns.countplot(df['22 Ease of navigation in website'],palette='Blues',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %% [markdown]
# People Strongly agree that website must be easy to use navigation among different pages on wesite must be easy.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='dark')
sns.countplot(df['23 Loading and processing speed'], palette='Oranges',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %% [markdown]
# People strongly agree that loading and processing speed of the website must be fast.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='dark')
sns.countplot(df['24 User friendly Interface of the website'], palette='YlGn',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='24 User friendly Interface of the website', ylabel='count'>

# %% [markdown]
# People strongly agree that website must be user-friendly.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['25 Convenient Payment methods'], palette='Reds', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %% [markdown]
# There should be convenient payment modes people had a very strong opnion about it.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'], palette='Blues')
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %% [markdown]
# People strongly believe that they trust online retail store will fulfill its part of the transaction at the stipulated time.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['27 Empathy (readiness to assist with queries) towards the customers'], palette='Oranges', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %% [markdown]
# People strongly believe that online platforms should always empatise towards the issues tey face while shopping online.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['28 Being able to guarantee the privacy of the customer'], palette='Greens', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %% [markdown]
# People strongly agree that these shopping online platforms should keep there information private.

# %%
plt.figure(figsize=(10,5))

sns.countplot(df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'], palette='Reds',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %% [markdown]
# People strongly believe that online platforms should be responsive enough and various communication shannels should be available to communicate.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['30 Online shopping gives monetary benefit and discounts'], palette='YlGn',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %% [markdown]
# People Strongly agree that online shoping gives monetary benifits and discounts.

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='2 How old are you?', hue='30 Online shopping gives monetary benefit and discounts', data=df, palette='colorblind',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# Almost verey age groups strongly agrees that online shoping gives monetary benefit.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='darkgrid')
plt.xticks(rotation=40)
g=sns.countplot(x='3 Which city do you shop online from?', hue='30 Online shopping gives monetary benefit and discounts', data=df,palette='muted',edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# People at every location agrees that online shoping gives monetary benefits and Discounts but People at Moradabad location strongly disagrees.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['31 Enjoyment is derived from shopping online'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %% [markdown]
# People Strongly agrees that they enjoy while shopping online.

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='2 How old are you?', hue='31 Enjoyment is derived from shopping online', data=df, edgecolor='black',palette='muted')
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %% [markdown]
# Most of the people agree that they enjoy while shoping but the people of age group 31-40 years think indifferenly about it.

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='dark')
sns.countplot(df['33 Return and replacement policy of the e-tailer is important for purchase decision'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %% [markdown]
# people strongly agree that the return and replacemnet ploicy of e-retailer is important before making nay pruchase.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['34 Gaining access to loyalty programs is a benefit of shopping online'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='34 Gaining access to loyalty programs is a benefit of shopping online', ylabel='count'>

# %% [markdown]
# People Strongly agree that gaining acess to loyality programs is a benefit of online shoping.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['35 Displaying quality Information on the website improves satisfaction of customers'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %% [markdown]
# People strongly agree that it is very important to display quality information.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['37 Net Benefit derived from shopping online can lead to users satisfaction'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %% [markdown]
# People strongly agree that bet benefit derived from shopping online can leads to customer satisfaction.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['38 User satisfaction cannot exist without trust'], palette='Accent', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %% [markdown]
# people strongly agree that user satisfaction cannot exsist without trust.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['39 Offering a wide variety of listed product in several category'], edgecolor='black', palette='Accent')
# Out:
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %% [markdown]
# People strongly agree that wesite should offer a wide variety in the listed product category.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['40 Provision of complete and relevant product information'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %% [markdown]
# People Strongly agree that website should provide a complete and relevant product information.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['41 Monetary savings'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='count'>

# %% [markdown]
# People Strongly agree that Online shopping helps in monetary savings.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['43 Shopping on the website gives you the sense of adventure'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %% [markdown]
# People says that shopping online gives them sense of adventure.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['44 Shopping on your preferred e-tailer enhances your social status'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %% [markdown]
# People have very indifferent views when asked about there opnion that shopping on the preferred e-retail store enhances there social status.

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style='dark')
plt.xticks(rotation=40)
g=sns.countplot(x='3 Which city do you shop online from?', hue='44 Shopping on your preferred e-tailer enhances your social status', data=df, palette='Accent', edgecolor='black')
g.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# when different city people were questioned about whether shopping online from different e-retail store enhances social status....
# 1. People in Delhi, Bangalore, Solan and Gurgaon and Bulanshahrthink indifferently about it.
# 2. People in G.Noida, Karnal, Noida, Merrut and Ghaziabad strongly agrees with the opion that there socail status is enhanced.
# 3. People in Moradabad Completely disagrees.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['45 You feel gratification shopping on your favorite e-tailer'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %% [markdown]
# People think indefifferently when asked about whether they feel gratified on shopping from there favourite e-retailor.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['46 Shopping on the website helps you fulfill certain roles'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %% [markdown]
# People think when indifferently when asked about whether online shopping helps them to fulfill certain roles.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['47 Getting value for money spent'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %% [markdown]
# People completely agree that they get valye of there money when spend online.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.set_theme(style='darkgrid')
sns.countplot(df['From the following, tick any (or all) of the online retailers you have shopped from;'], palette='dark', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='From the following, tick any (or all) of the online retailers you have shopped from;', ylabel='count'>

# %% [markdown]
# People prefer Amazon, Flipcart, Paytm, Myntra, Snapdeal.com to shop online.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(x='From the following, tick any (or all) of the online retailers you have shopped from;', hue='41 Monetary savings', data=df, palette='pastel', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='From the following, tick any (or all) of the online retailers you have shopped from;', ylabel='count'>

# %% [markdown]
# People Strongly agree that amazone, flipkart, paytm, Myntra and snapdeal are the sites that help them in monetary savings.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Easy to use website or application'], edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Easy to use website or application', ylabel='count'>

# %% [markdown]
# Amazone.com, Flipkart.com, Paytm.com and Snapdeal.com are the websites taht are easy to use and understand.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(x='Easy to use website or application', hue='25 Convenient Payment methods', data=df, edgecolor='black', palette='muted')
# Out:
# <AxesSubplot:xlabel='Easy to use website or application', ylabel='count'>

# %% [markdown]
# Paytm is the website where few people disagrees that this site provides us convenient method of payments as compared to other websites.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Visual appealing web-page layout'], palette='dark', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Visual appealing web-page layout', ylabel='count'>

# %% [markdown]
# Amazon and flipkarts are the websites that are visually appealing to its customers.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Wild variety of product on offer'],palette='dark', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Wild variety of product on offer', ylabel='count'>

# %% [markdown]
# Amazon and Flipkart offers wide variety of products as compared to other websites.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Complete, relevant description information of products'],palette='dark', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Complete, relevant description information of products', ylabel='count'>

# %% [markdown]
# Amazon and Flipkarts are the websites that provide complete and relevant information as compared to other websites.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Fast loading website speed of website and application'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Fast loading website speed of website and application', ylabel='count'>

# %% [markdown]
# Amazon.in is the fastest loading website as compared to any other website.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Reliability of the website or application'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Reliability of the website or application', ylabel='count'>

# %% [markdown]
# Amazon.in is comsidered to be the most relaible site.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Quickness to complete purchase'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Quickness to complete purchase', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Availability of several payment options'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Availability of several payment options', ylabel='count'>

# %% [markdown]
# Amazon.in is the website which has the availability of several payment options.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Speedy order delivery'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Speedy order delivery', ylabel='count'>

# %% [markdown]
# amazon.in provides us with thwe fastest delivery.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Privacy of customers� information'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Privacy of customers� information', ylabel='count'>

# %% [markdown]
# Amazon.in is the bestest online platform that keep its customer infomation private as compared to other platforms.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Security of customer financial information'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Security of customer financial information', ylabel='count'>

# %% [markdown]
# amazon.in secured higest counts in keeping the security of its customer financial information.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Perceived Trustworthiness'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Perceived Trustworthiness', ylabel='count'>

# %% [markdown]
# Amazon.in has won the trust of its customers.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Presence of online assistance through multi-channel'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Presence of online assistance through multi-channel', ylabel='count'>

# %% [markdown]
# Amazon.in is the platform that has made its presence through various multimedia channels.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Longer time to get logged in (promotion, sales period)'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Longer time to get logged in (promotion, sales period)', ylabel='count'>

# %% [markdown]
# Amazon.in is the site that takes longer time to logg in as compaed to other websites.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Longer time in displaying graphics and photos (promotion, sales period)'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)', ylabel='count'>

# %% [markdown]
# Amazon and Flipkart takes longer time to display information as compared to other websites.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Late declaration of price (promotion, sales period)'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)', ylabel='count'>

# %% [markdown]
# Myntra.in takes longer time to display the price

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Longer page loading time (promotion, sales period)'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Longer page loading time (promotion, sales period)', ylabel='count'>

# %% [markdown]
# Myntra.com takes long time to load the page followed by Flipkart.com

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Limited mode of payment on most products (promotion, sales period)'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='count'>

# %% [markdown]
# Snapdeal.com provides us with the limited mode of payment.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Longer delivery period'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Longer delivery period', ylabel='count'>

# %% [markdown]
# Paytm.in is the website that takes longer delivery period as compared to other websites.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Change in website/Application design'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Change in website/Application design', ylabel='count'>

# %% [markdown]
# Amazon.in keep chnaging its webiste i.e its design layout more frequently than any other.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Frequent disruption when moving from one page to another'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Frequent disruption when moving from one page to another', ylabel='count'>

# %% [markdown]
# when moving from one page to another there is frequent disruptions on amazon.in followed by Myntra and snapdeal.

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(df['Which of the Indian online retailer would you recommend to a friend?'],edgecolor='black')
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='count'>

# %% [markdown]
# Amazon.in is considered as one of the most recommended website by the people.
