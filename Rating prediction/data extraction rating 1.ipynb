# %%
#importing the required libraries
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
import time

# %%
#connecting with the drivers
driver=webdriver.Chrome(r"C:\Users\MICROSOFT\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
#connecting with the website extracting information from flipkart for laptop
driver.get("https://www.flipkart.com/dell-inspiron-core-i5-10th-gen-8-gb-512-gb-ssd-windows-10-home-ins-5408-thin-light-laptop/product-reviews/itmc78f94d1da92c?pid=COMFUZ3JZ6VQZN9Y&page=1")

# %%
ratingflip=[] #extracting rating given by users and appending it in list.

def rating():
    rati=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']")
    for i in rati:
        ratingflip.append(i.text)
    return(ratingflip)

# %%
review2=[] #extracting reviews and appending it in list.
def review():
    rev=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
    for i in rev:
        review2.append(i.text.replace("\n"," "))
    return(review2)

# %%
i=0
while(i<6):
    try:
        driver.find_elements_by_xpath("//a[@class='_1LKTO3']")[-1].click() #(clicking on the next button to reach last)
        rating()
        review()
    except:
        pass
        
    i=i+1

# %%
rating()
# Out:
# ['5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '2',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '2',
#  '4',
#  '5',
#  '2',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '3',
#  '3',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '3',
#  '3',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4']

# %%
len(ratingflip)
# Out:
# 45

# %%
review()
# Out:
# ["Everything is nice about this product as mentioned. Just the backlit, having it or not doesn't matter. Very low. Only con there I realize. No heating issue for me, I don't watch movie or play games so no idea about the graphics. Overall I loved it, even my cousin was astonished saying that he didn't had any idea Dell Laptops could be this eye catching... 🤭... And for me screen size is great!",
#  'Its an amazing experience to work on this laptop. its been 3-4months of intensive usage as i am a research student. The softwares have been running extremely smoothly and the boot is very fast! it has touch id, backlit, ssd almost all the features i was looking for!',
#  "I did research on laptops for past 2 weeks and finally made the decision of getting myself Dell Inspiron 5408 series. Let's start with each points.  Looks : Premium design, diamond cut hand rest which gives it a classy finish. The backside is quite similar to the mac air which is also good.  Performance: I use them for content typing, editing, presentations, online conferences, mostly all of these at the same time. So, multi-tasking really works well with the i5 processor. The camera quality ... READ MORE",
#  'First Of All, I am writing this review after using this laptop 1 month and trust me this is an awesome laptop . Also, I have read one review from a person who had ordered this laptop and was facing problem with audio jack. So, to that person and all of you I want to say that audio jack is in completely good condition you just need to update some drivers then it will works well.  Now, Display- its display is just amazing and colours are very vibrant and punchy.  Keyboard- Its keyboard is very... READ MORE',
#  'All as described. Finally a speedy experience at a nominal price. Also the keypad is very soft. Really works wonder with typing. Battery backup is average. Light weight so can work for long hrs. With i5, the speed is awesome. Loving it so far.',
#  "Audio jack is not working. Recieved defective product. And no option for replacement. Dell assured me that product need to be replaced but flipkart is not replacing the product and keeps on postponing the date of replacement. Horrible experience of buying laptop from flipkart. It's been more than 18 days and flipkart is keeping on expanding the date of replacement. Terrible customer support and worst experience.",
#  "It looks perfectly fine, I ordered it on 30 Oct and received it on Nov 1. It's working fine",
#  "This is my initial review. It's really volue for money product. One touch unlock is precise. Light weight. And backlit keyboard. Good for personal use.I will give final review after some time.",
#  'Normal office, college and school work, social media, entertainment etc goo for it. Good camera, speaker, battery life, design, body, etc modern ports. The best you can get in this price range.',
#  'Product is very good. But not loo lightweight and not so thin ..',
#  'Before 5 months I Bought this, and now suffering from hanging , slow down and filling almost 250 gb storage of C drive after repeated update. Called to Customer care ...but guarantee is on hardware only has replied....not satisfied',
#  'Slim n sleek design.... performance is good, display n spekaers are better than the other in this range',
#  'Using from last one month. So far so good . No issue . Battery is good enough. Performance is excellent. Awsome look',
#  'Good laptop ,batter backup is good ,screen quality,sound is best ,figer print scanner ,backlit keyboard works perfect.',
#  'I have experienced a problem while connecting to headset. Otherwise it is a worth product',
#  'Great product.',
#  'Delivery experience was great ......and product is awesome....looking cute luxury....and power house in terms of technical',
#  "flipkart Delivered laptop to me on 7th Nov 2020 - Saturday evening Initially laptop had major startup and hanging problems for first 4 days. Contacted DEL support and DEL hardware engineer updated all the drivers , even though Issues of laptop wasn't fixed. After making lot of noise with DEL, DEL hardware engineer done some major Bios Updates(may be properly done hardware updates) & OS updates. After that from last 2 days laptop is working perfect . So far no issues. 5408 is good looki... READ MORE",
#  'Very good product in 60k range',
#  'Nice product',
#  'Before 5 months I Bought this, and now suffering from hanging , slow down and filling almost 250 gb storage of C drive after repeated update. Called to Customer care ...but guarantee is on hardware only has replied....not satisfied',
#  'Slim n sleek design.... performance is good, display n spekaers are better than the other in this range',
#  'Using from last one month. So far so good . No issue . Battery is good enough. Performance is excellent. Awsome look',
#  'Good laptop ,batter backup is good ,screen quality,sound is best ,figer print scanner ,backlit keyboard works perfect.',
#  'I have experienced a problem while connecting to headset. Otherwise it is a worth product',
#  'Great product.',
#  'Delivery experience was great ......and product is awesome....looking cute luxury....and power house in terms of technical',
#  "flipkart Delivered laptop to me on 7th Nov 2020 - Saturday evening Initially laptop had major startup and hanging problems for first 4 days. Contacted DEL support and DEL hardware engineer updated all the drivers , even though Issues of laptop wasn't fixed. After making lot of noise with DEL, DEL hardware engineer done some major Bios Updates(may be properly done hardware updates) & OS updates. After that from last 2 days laptop is working perfect . So far no issues. 5408 is good looki... READ MORE",
#  'Very good product in 60k range',
#  'Nice product',
#  'Before 5 months I Bought this, and now suffering from hanging , slow down and filling almost 250 gb storage of C drive after repeated update. Called to Customer care ...but guarantee is on hardware only has replied....not satisfied',
#  'Slim n sleek design.... performance is good, display n spekaers are better than the other in this range',
#  'Using from last one month. So far so good . No issue . Battery is good enough. Performance is excellent. Awsome look',
#  'Good laptop ,batter backup is good ,screen quality,sound is best ,figer print scanner ,backlit keyboard works perfect.',
#  'I have experienced a problem while connecting to headset. Otherwise it is a worth product',
#  'Great product.',
#  'Delivery experience was great ......and product is awesome....looking cute luxury....and power house in terms of technical',
#  "flipkart Delivered laptop to me on 7th Nov 2020 - Saturday evening Initially laptop had major startup and hanging problems for first 4 days. Contacted DEL support and DEL hardware engineer updated all the drivers , even though Issues of laptop wasn't fixed. After making lot of noise with DEL, DEL hardware engineer done some major Bios Updates(may be properly done hardware updates) & OS updates. After that from last 2 days laptop is working perfect . So far no issues. 5408 is good looki... READ MORE",
#  'Very good product in 60k range',
#  'Nice product',
#  'Slim and Portable laptop. The spec is amazing at this price range(59K) and the build quality is superb.',
#  'Pros, Pros and Pros. No Cons.. Loved',
#  'Very Nice Product. Battery and Performance is also great. Value for Money. Premium Sleek Design.',
#  'Just one word ...wow Amazing laptop. I wanted this for my personal use...it definitmeets my expectation....i got it at a cheaper rate in the sale....again the price has gone up....overall a very good deal. Really happy. Feels premium when you hold it...',
#  'Very premium finish Display is awesome I have used it for one week. On general use battery lasted 6-7 hrs I felt the key travel is not good enough. Rest all is god']

# %%
len(review2)
# Out:
# 45

# %%
jobr=pd.DataFrame({})    #creating a data frame and storing the data in each row aand colum.
jobr["Rating"]=ratingflip
jobr["Review"]=review2
jobr
# Out:
#    Rating                                             Review
# 0       5  Everything is nice about this product as menti...
# 1       5  Its an amazing experience to work on this lapt...
# 2       5  I did research on laptops for past 2 weeks and...
# 3       5  First Of All, I am writing this review after u...
# 4       5  All as described. Finally a speedy experience ...
# 5       2  Audio jack is not working. Recieved defective ...
# 6       5  It looks perfectly fine, I ordered it on 30 Oc...
# 7       5  This is my initial review. It's really volue f...
# 8       5  Normal office, college and school work, social...
# 9       5  Product is very good. But not loo lightweight ...
# 10      4  Before 5 months I Bought this, and now sufferi...
# 11      2  Slim n sleek design.... performance is good, d...
# 12      4  Using from last one month. So far so good . No...
# 13      5  Good laptop ,batter backup is good ,screen qua...
# 14      2  I have experienced a problem while connecting ...
# 15      5                                     Great product.
# 16      5  Delivery experience was great ......and produc...
# 17      5  flipkart Delivered laptop to me on 7th Nov 202...
# 18      4                     Very good product in 60k range
# 19      5                                       Nice product
# 20      3  Before 5 months I Bought this, and now sufferi...
# 21      3  Slim n sleek design.... performance is good, d...
# 22      5  Using from last one month. So far so good . No...
# 23      5  Good laptop ,batter backup is good ,screen qua...
# 24      3  I have experienced a problem while connecting ...
# 25      5                                     Great product.
# 26      5  Delivery experience was great ......and produc...
# 27      4  flipkart Delivered laptop to me on 7th Nov 202...
# 28      5                     Very good product in 60k range
# 29      5                                       Nice product
# 30      3  Before 5 months I Bought this, and now sufferi...
# 31      3  Slim n sleek design.... performance is good, d...
# 32      5  Using from last one month. So far so good . No...
# 33      5  Good laptop ,batter backup is good ,screen qua...
# 34      3  I have experienced a problem while connecting ...
# 35      5                                     Great product.
# 36      5  Delivery experience was great ......and produc...
# 37      4  flipkart Delivered laptop to me on 7th Nov 202...
# 38      5                     Very good product in 60k range
# 39      5                                       Nice product
# 40      5  Slim and Portable laptop. The spec is amazing ...
# 41      5               Pros, Pros and Pros. No Cons.. Loved
# 42      5  Very Nice Product. Battery and Performance is ...
# 43      5  Just one word ...wow Amazing laptop. I wanted ...
# 44      4  Very premium finish Display is awesome I have ...

# %%
jobr.drop_duplicates(inplace=True)

# %%
jobr
# Out:
#    Rating                                             Review
# 0       5  Everything is nice about this product as menti...
# 1       5  Its an amazing experience to work on this lapt...
# 2       5  I did research on laptops for past 2 weeks and...
# 3       5  First Of All, I am writing this review after u...
# 4       5  All as described. Finally a speedy experience ...
# 5       2  Audio jack is not working. Recieved defective ...
# 6       5  It looks perfectly fine, I ordered it on 30 Oc...
# 7       5  This is my initial review. It's really volue f...
# 8       5  Normal office, college and school work, social...
# 9       5  Product is very good. But not loo lightweight ...
# 10      4  Before 5 months I Bought this, and now sufferi...
# 11      2  Slim n sleek design.... performance is good, d...
# 12      4  Using from last one month. So far so good . No...
# 13      5  Good laptop ,batter backup is good ,screen qua...
# 14      2  I have experienced a problem while connecting ...
# 15      5                                     Great product.
# 16      5  Delivery experience was great ......and produc...
# 17      5  flipkart Delivered laptop to me on 7th Nov 202...
# 18      4                     Very good product in 60k range
# 19      5                                       Nice product
# 20      3  Before 5 months I Bought this, and now sufferi...
# 21      3  Slim n sleek design.... performance is good, d...
# 22      5  Using from last one month. So far so good . No...
# 24      3  I have experienced a problem while connecting ...
# 27      4  flipkart Delivered laptop to me on 7th Nov 202...
# 28      5                     Very good product in 60k range
# 40      5  Slim and Portable laptop. The spec is amazing ...
# 41      5               Pros, Pros and Pros. No Cons.. Loved
# 42      5  Very Nice Product. Battery and Performance is ...
# 43      5  Just one word ...wow Amazing laptop. I wanted ...
# 44      4  Very premium finish Display is awesome I have ...

# %%
#contecting with the website flipkart and extracting reviews of iphone 11.
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART")

# %%
counter = 0
data = []

while(counter<1000):
    reviews_deck = driver.find_elements(By.XPATH,"//div[@class='col _2wzgFH K0kLPL']")    
    for review in reviews_deck:
        
        if(counter>1000):
            break
        else:
            counter+=1
        try:
            review.find_element(By.XPATH,".//div[@class='row']//span[@class='_1BWGvX']").click()
        except:
            pass
        finally:
            rating, review_desc = review.find_elements(By.XPATH,".//div[@class='row']")[:2]
            rating_stars, rating_desc = rating.text[0],rating.text[1:]
        
        rating_stars_ = rating_stars.strip()
        rating_desc_ = rating_desc.strip()
        review_desc_ = review_desc.text.strip()
        data.append([rating_stars_, rating_desc_, review_desc_])
    try:
        driver.find_element(By.XPATH,"//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        driver.find_element(By.XPATH,"//a[@class='_1LKTO3']/span").click()
        time.sleep(2)

# %%
columns = ['Rating', 'Rating Summary', 'Review']
df = pd.DataFrame(data, columns=columns)

# %%
df.head()
# Out:
#   Rating       Rating Summary  \
# 0      5            Brilliant
# 1      5       Simply awesome
# 2      5  Best in the market!
# 3      5     Perfect product!
# 4      5    Worth every penny
#
#                                               Review
# 0  The Best Phone for the Money\n\nThe iPhone 11 ...
# 1  Really satisfied with the Product I received.....
# 2  Great iPhone very snappy experience as apple k...
# 3  Amazing phone with great cameras and better ba...
# 4  Previously I was using one plus 3t it was a gr...

# %%
df.tail()
# Out:
#     Rating     Rating Summary  \
# 995      1    Waste of money!
# 996      5  Terrific purchase
# 997      5            Awesome
# 998      5           Terrific
# 999      3          Just okay
#
#                                                 Review
# 995  I am writing this review after using phone for...
# 996       Awesome apple product loved the purple pearl
# 997  battery issue, battery health is 100 and batte...
# 998    This phone has changed my carrier. Thanks Apple
# 999  Superb camera\nExcellent battery life\nAmazing...

# %%
df.drop("Rating Summary", axis=1, inplace=True)

# %%
df.tail()
# Out:
#     Rating                                             Review
# 995      1  I am writing this review after using phone for...
# 996      5       Awesome apple product loved the purple pearl
# 997      5  battery issue, battery health is 100 and batte...
# 998      5    This phone has changed my carrier. Thanks Apple
# 999      3  Superb camera\nExcellent battery life\nAmazing...

# %%
#connecting with the website and extracting information for MI products
driver.get("https://www.flipkart.com/redmi-9a-midnight-black-32-gb/product-reviews/itmeabd39a0cd669?pid=MOBFVDA2RWTCFBHZ&lid=LSTMOBFVDA2RWTCFBHZL6SCWL&aid=overall&certifiedBuyer=false&sortOrder=NEGATIVE_FIRST")

# %%
counter = 0
data = []

while(counter<500):
    reviews_deck = driver.find_elements(By.XPATH,"//div[@class='col _2wzgFH K0kLPL']")    
    for review in reviews_deck:
        
        if(counter>500):
            break
        else:
            counter+=1
        try:
            review.find_element(By.XPATH,".//div[@class='row']//span[@class='_1BWGvX']").click()
        except:
            pass
        finally:
            rating, review_desc = review.find_elements(By.XPATH,".//div[@class='row']")[:2]
            rating_stars, rating_desc = rating.text[0],rating.text[1:]
        
        rating_stars_ = rating_stars.strip()
        rating_desc_ = rating_desc.strip()
        review_desc_ = review_desc.text.strip().replace("\n"," ")
        data.append([rating_stars_, rating_desc_, review_desc_])
    try:
        driver.find_element(By.XPATH,"//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        driver.find_element(By.XPATH,"//a[@class='_1LKTO3']/span").click()
        time.sleep(2)

# %%
columns = ['Rating', 'Rating Summary', 'Review']
df2 = pd.DataFrame(data, columns=columns)

# %%
df2.head()
# Out:
#   Rating          Rating Summary  \
# 0      1  Don't waste your money
# 1      1    Utterly Disappointed
# 2      1                Horrible
# 3      1          Unsatisfactory
# 4      1  Worst experience ever!
#
#                                               Review
# 0                                    Hanging problem
# 1                                           It hangs
# 2                                      Speaker issue
# 3  flipkart from the last 2 product delivery i am...
# 4                              Feeling hanging issue

# %%
df2.tail()
# Out:
#     Rating     Rating Summary  \
# 496      5   Perfect product!
# 497      5          Must buy!
# 498      5  Terrific purchase
# 499      5     Simply awesome
# 500      5  Worth every penny
#
#                                                 Review
# 496                           Good phone in this price
# 497  Nice product with in this budget.... Great scr...
# 498                                       Best picture
# 499                                  Excellent quality
# 500                             Nice model Nice mobile

# %%
#conecting with the website and extracting the informtaion for vivo products
driver.get("https://www.flipkart.com/vivo-y33s-mirror-black-128-gb/product-reviews/itm4121bc2b6ca4a?pid=MOBG5Y8CGTMKZFV6&lid=LSTMOBG5Y8CGTMKZFV6XGKSN8&aid=overall&certifiedBuyer=false&sortOrder=NEGATIVE_FIRST")

# %%
counter = 0
data = []

while(counter<500):
    reviews_deck = driver.find_elements(By.XPATH,"//div[@class='col _2wzgFH K0kLPL']")    
    for review in reviews_deck:
        
        if(counter>500):
            break
        else:
            counter+=1
        try:
            review.find_element(By.XPATH,".//div[@class='row']//span[@class='_1BWGvX']").click()
        except:
            pass
        finally:
            rating, review_desc = review.find_elements(By.XPATH,".//div[@class='row']")[:2]
            rating_stars, rating_desc = rating.text[0],rating.text[1:]
        
        rating_stars_ = rating_stars.strip()
        rating_desc_ = rating_desc.strip()
        review_desc_ = review_desc.text.strip().replace("\n"," ")
        data.append([rating_stars_, rating_desc_, review_desc_])
    try:
        driver.find_element(By.XPATH,"//a[@class='_1LKTO3'][2]/span").click()
        time.sleep(1)
    except:
        driver.find_element(By.XPATH,"//a[@class='_1LKTO3']/span").click()
        time.sleep(2)

# %%
columns = ['Rating', 'Rating Summary', 'Review']
df3 = pd.DataFrame(data, columns=columns)

# %%
df3.tail()
# Out:
#     Rating  Rating Summary                                             Review
# 365      5       Just wow!  Everything is good only issues is Bluetooth co...
# 366      5        Terrific                                               Good
# 367      5       Fabulous!  Very Good product in this price, Performance i...
# 368      5         Awesome                                         Nice.,....
# 369      5  Classy product                                               Good

# %%
frames1=[jobr,df,df2,df3]
df7=pd.concat(frames1)
df7 #concatinating frames in one frame
# Out:
#     Rating                                             Review  Rating Summary
# 0        5  Everything is nice about this product as menti...             NaN
# 1        5  Its an amazing experience to work on this lapt...             NaN
# 2        5  I did research on laptops for past 2 weeks and...             NaN
# 3        5  First Of All, I am writing this review after u...             NaN
# 4        5  All as described. Finally a speedy experience ...             NaN
# ..     ...                                                ...             ...
# 365      5  Everything is good only issues is Bluetooth co...       Just wow!
# 366      5                                               Good        Terrific
# 367      5  Very Good product in this price, Performance i...       Fabulous!
# 368      5                                         Nice.,....         Awesome
# 369      5                                               Good  Classy product
#
# [1902 rows x 3 columns]

# %%
df7.to_csv("newdataset.csv")
